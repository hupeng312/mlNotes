# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
boston = datasets.load_boston()

# %%
x = boston.data[:,5]
y = boston.target

plt.scatter(x, y)

# %%
x = x[y < 50]
y = y[y < 50]

# %%
plt.scatter(x, y)

# %%
# %run SimpleLinearRegression.py
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=666)

# %%
linear = SimpleLinearRegression2()
linear.fit(x, y)
# Out:
# SimpleLinearRegression1()

# %%
plt.scatter(x ,y)
plt.plot(x, linear.predict(x), color='r')
plt.plot(x_test, linear.predict(x_test), color='y')

# %% [markdown]
# ## MSE

# %%
y_test_predict = linear.predict(x_test)
mse_test = np.sum((y_test_predict - y_test) ** 2) / len(y_test)
mse_test
# Out:
# 23.515955306671096

# %% [markdown]
# ## RMSE

# %%
from math import sqrt

rmse_test = sqrt(mse_test)
rmse_test
# Out:
# 4.849325242409617

# %%
mae_test = np.sum(np.absolute(y_test_predict - y_test)) / len(y_test)
mae_test
# Out:
# 3.4820029567021606

# %% [markdown]
# ## sklearn 中的MSE和MAE

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_test_predict)
# Out:
# 3.4820029567021606

# %%
mean_squared_error(y_test, y_test_predict)
# Out:
# 23.515955306671096

# %% [markdown]
# ## R_Squared

# %%
# %run metrics.py

# %%
r2_score(y_test, y_test_predict)
# Out:
# 0.62319695237551709
